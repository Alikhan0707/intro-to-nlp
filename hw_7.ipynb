# %% [markdown]
# Берем отызывы за лето (из архива с материалами или предыдущего занятия)

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
import tensorflow as tf

# %% [markdown]
# ### Загрузка данных

# %%
reviews = pd.read_excel('отзывы за лето (1).xls')

# %%
reviews.head()
# Out:
#    Rating                                            Content        Date
# 0       5                                     It just works!  2017-08-14
# 1       4  В целом удобноное приложение...из минусов хотя...  2017-08-14
# 2       5                                        Отлично все  2017-08-14
# 3       5  Стал зависать на 1% работы антивируса. Дальше ...  2017-08-14
# 4       5                     Очень удобно, работает быстро.  2017-08-14

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20659 entries, 0 to 20658
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rating   20659 non-null  int64
#  1   Content  20656 non-null  object
#  2   Date     20659 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 484.3+ KB

# %%
reviews.Rating.value_counts()
# Out:
# 5    14586
# 1     2276
# 4     2138
# 3      911
# 2      748
# Name: Rating, dtype: int64

# %%
reviews = reviews[['Content', 'Rating']]
reviews.columns = ['text', 'target']

# %%
reviews.head()
# Out:
#                                                 text  target
# 0                                     It just works!       5
# 1  В целом удобноное приложение...из минусов хотя...       4
# 2                                        Отлично все       5
# 3  Стал зависать на 1% работы антивируса. Дальше ...       5
# 4                     Очень удобно, работает быстро.       5

# %%
reviews['target'] = reviews['target'].apply(lambda x: (x - 1))

# %%
reviews['target'].value_counts()
# Out:
# 4    14586
# 0     2276
# 3     2138
# 2      911
# 1      748
# Name: target, dtype: int64

# %%
max_words = 200
max_len = 40
num_classes = 1

# %% [markdown]
# ### Разделение датасета на train и test

# %%
X_train, X_test, y_train, y_test = train_test_split(reviews['text'], reviews['target'], 
                                                   test_size=0.3, stratify=reviews['target'], 
                                                   shuffle=True, random_state=42)

# %% [markdown]
# ### Предобработка текста

# %%
from string import punctuation
from pymorphy2 import MorphAnalyzer
from stop_words import get_stop_words
import re

# %%
stopwords = set(get_stop_words('ru'))
exclude = set(punctuation)
morpher = MorphAnalyzer()

# %%
def preprocess_data(text):
    text = str(text)
    text = ''.join(c for c in text if c not in exclude)
    text = text.lower()
    text = re.sub('\sне', 'не', text)
    text = ' '.join([morpher.parse(word)[0].normal_form for word in text.split() if word not in stopwords])
    return text

# %%
X_train = X_train.apply(preprocess_data)
X_test = X_test.apply(preprocess_data)

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')

train_corpus = ' '.join(X_train)

tokens = word_tokenize(train_corpus)
# Out:
# [nltk_data] Downloading package punkt to /Users/macbook/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
tokens_filtered = [word for word in tokens if word.isalnum()]

# %%
from nltk.probability import FreqDist

dist = FreqDist(tokens_filtered)
tokens_filtered_top = [pair[0] for pair in dist.most_common(max_words - 1)]

# %%
vocabulary = {v: k for k, v in dict(enumerate(tokens_filtered_top, 1)).items()}

# %%
def text_to_sequence(text, maxlen):
    result = []
    tokens = word_tokenize(text.lower())
    tokens_filtered = [word for word in tokens if word.isalnum()]
    for word in tokens_filtered:
        if word in vocabulary:
            result.append(vocabulary[word])
    padding = [0] * (maxlen - len(result))
    return padding + result[-maxlen:]

# %%
X_train = np.asarray([text_to_sequence(text, max_len) for text in X_train], dtype=np.int32)
X_test = np.asarray([text_to_sequence(text, max_len) for text in X_test], dtype=np.int32)

# %% [markdown]
# ### Учим conv сеть для классификации

# %% [markdown]
# 2.2 Инициализировать слой tf.keras.layers.Embedding по умолчанию (ну то есть вам ничего не делать с весами)
# Сравнить две архитектуры с предобученными весами и когда tf.keras.layers.Embedding обучается сразу со всей сеточкой, что получилось лучше

# %%
y_test.value_counts()
# Out:
# 4    4376
# 0     683
# 3     642
# 2     273
# 1     224
# Name: target, dtype: int64

# %%
num_classes = 5
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Embedding(input_dim=max_words, output_dim=128, input_length=max_len))
model.add(tf.keras.layers.Conv1D(128, 3))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling1D())
model.add(tf.keras.layers.Conv1D(64, 16))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPool1D())
model.add(tf.keras.layers.Conv1D(32, 1))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling1D())
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(32))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Dense(16))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Dense(5))
model.add(tf.keras.layers.Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

# %%
tensorboard = tf.keras.callbacks.TensorBoard(log_dir='./logs', write_graph=True, write_images=True)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss')

# %%
epochs = 20
batch_size = 512
print_batch_n = 100

history = model.fit(X_train, y_train, 
                    batch_size=batch_size,
                    epochs=epochs, 
                    verbose=1, 
                    validation_split=0.1, 
#                     callbacks=[tensorboard, early_stopping]
                   )
# Out:
# Epoch 1/20
# 26/26 [==============================] - 5s 147ms/step - loss: 1.2188 - accuracy: 0.7016 - val_loss: 0.9705 - val_accuracy: 0.7015
# Epoch 2/20
# 26/26 [==============================] - 4s 139ms/step - loss: 0.9308 - accuracy: 0.7105 - val_loss: 0.8495 - val_accuracy: 0.7284
# Epoch 3/20
# 26/26 [==============================] - 4s 139ms/step - loss: 0.7872 - accuracy: 0.7412 - val_loss: 0.7400 - val_accuracy: 0.7581
# Epoch 4/20
# 26/26 [==============================] - 4s 139ms/step - loss: 0.7131 - accuracy: 0.7573 - val_loss: 0.7032 - val_accuracy: 0.7664
# Epoch 5/20
# 26/26 [==============================] - 4s 151ms/step - loss: 0.6893 - accuracy: 0.7630 - val_loss: 0.7033 - val_accuracy: 0.7657
# Epoch 6/20
# 26/26 [==============================] - 4s 149ms/step - loss: 0.6825 - accuracy: 0.7639 - val_loss: 0.6983 - val_accuracy: 0.7643
# Epoch 7/20
# 26/26 [==============================] - 4s 143ms/step - loss: 0.6783 - accuracy: 0.7648 - val_loss: 0.6981 - val_accuracy: 0.7650
# Epoch 8/20
# 26/26 [==============================] - 4s 143ms/step - loss: 0.6753 - accuracy: 0.7669 - val_loss: 0.6952 - val_accuracy: 0.7685
# Epoch 9/20
# 26/26 [==============================] - 4s 155ms/step - loss: 0.6710 - accuracy: 0.7678 - val_loss: 0.7011 - val_accuracy: 0.7692
# Epoch 10/20
# 26/26 [==============================] - 4s 148ms/step - loss: 0.6684 - accuracy: 0.7673 - val_loss: 0.7007 - val_accuracy: 0.7685
# Epoch 11/20
# 26/26 [==============================] - 4s 163ms/step - loss: 0.6642 - accuracy: 0.7693 - val_loss: 0.6959 - val_accuracy: 0.7664
# Epoch 12/20
# 26/26 [==============================] - 4s 156ms/step - loss: 0.6610 - accuracy: 0.7691 - val_loss: 0.6930 - val_accuracy: 0.7643
# Epoch 13/20
# 26/26 [==============================] - 4s 161ms/step - loss: 0.6597 - accuracy: 0.7713 - val_loss: 0.6941 - val_accuracy: 0.7623
# Epoch 14/20
# 26/26 [==============================] - 4s 165ms/step - loss: 0.6554 - accuracy: 0.7703 - val_loss: 0.6956 - val_accuracy: 0.7685
# Epoch 15/20
# 26/26 [==============================] - 4s 152ms/step - loss: 0.6552 - accuracy: 0.7703 - val_loss: 0.6958 - val_accuracy: 0.7664
# Epoch 16/20
# 26/26 [==============================] - 4s 160ms/step - loss: 0.6497 - accuracy: 0.7718 - val_loss: 0.7001 - val_accuracy: 0.7685
# Epoch 17/20
# 26/26 [==============================] - 4s 168ms/step - loss: 0.6497 - accuracy: 0.7720 - val_loss: 0.6932 - val_accuracy: 0.7671
# Epoch 18/20
# 26/26 [==============================] - 4s 154ms/step - loss: 0.6438 - accuracy: 0.7736 - val_loss: 0.6998 - val_accuracy: 0.7678
# Epoch 19/20
# 26/26 [==============================] - 4s 154ms/step - loss: 0.6422 - accuracy: 0.7747 - val_loss: 0.6962 - val_accuracy: 0.7664
# Epoch 20/20
# 26/26 [==============================] - 4s 163ms/step - loss: 0.6383 - accuracy: 0.7755 - val_loss: 0.6973 - val_accuracy: 0.7664

# %%
metrics_table = []
metrics_table.append(model.evaluate(X_test, y_test))
# Out:
# 194/194 [==============================] - 1s 4ms/step - loss: 0.6820 - accuracy: 0.7638

# %% [markdown]
# 2. Рассмотреть 2-а варианта сеточек

# %% [markdown]
# 2.1 Инициализировать tf.keras.layers.Embedding предобученными векторами взять к примеру с https://rusvectores.org/ru/

# %%
from zipfile import ZipFile
from gensim.models import KeyedVectors, KeyedVectors

# with ZipFile('181.zip', 'r') as archive:
#     stream = archive.open('model.model')
#     model = KeyedVectors.load_word2vec_format(stream, binary=True)

# %%
model = KeyedVectors.load('181/model.model')

# %%
X_train, X_test, y_train, y_test = train_test_split(reviews['text'], reviews['target'], 
                                                   test_size=0.3, stratify=reviews['target'], 
                                                   shuffle=True, random_state=42)

# %%
reviews['vecs'] = reviews['text'].apply(lambda x: [model[word] for word in str(x).split()])

# %%
np.array([np.asarray(i, dtype=np.float32) for i in reviews.vecs.values])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-e0e6d52e53ea> in <module>
# ----> 1 np.asarray([np.asarray(i, dtype=np.float32) for i in reviews.vecs.values], dtype=np.float32)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: setting an array element with a sequence.

# %%
np.asarray(reviews.vecs.values, dtype=np.float32)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-278348c04672> in <module>
# ----> 1 np.asarray(reviews.vecs.values, dtype=np.float32)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: setting an array element with a sequence.
